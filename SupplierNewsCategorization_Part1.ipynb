# %% [markdown]
# Data Loading and initial preprocessing

# %%
import pandas as pd

# Load the dataset
file_path = '/content/newsdata.csv'
df = pd.read_csv(file_path)

# Preview the dataset
print(df.head())
# Out:
#           Date                                              Title  \
# 0  28 Sep 2024  Forvia Hella begins making RGB LED rear combin...
# 1  28 Sep 2024  Continental named among top 500 sustainable co...
# 2  28 Sep 2024  Stellantis honours 68 global and regional supp...
# 3  27 Sep 2024  Schaeffler names new CFO ahead of expected mer...
# 4  27 Sep 2024  China requests US to stop 'unreasonable suppre...
#
#                   Author                                               Tags  \
# 0  Autocar Pro News Desk  ['Lynk & Co', 'Geely Auto', 'Forvia Hella', 'R...
# 1  Autocar Pro News Desk  ['Continental', 'Continental Tires', "world's ...
# 2  Autocar Pro News Desk  ['Stellantis', 'Stellantis Supplier of the Yea...
# 3  Autocar Pro News Desk             ['Vitesco Technologies', 'Schaeffler']
# 4  Autocar Pro News Desk                                                 []
#
#    Related Organzation                                            Content  \
# 0                  NaN  The rear lamp is used in the Geely Auto Group’...
# 1                  NaN  Continental ranked 265th in Time and Statista’...
# 2                  NaN  Fourth annual Stellantis Supplier of the Year ...
# 3                  NaN  Schaeffler has also announced the appointment ...
# 4                  NaN  "The U.S. move has no factual basis, violates ...
#
#                                                 Link
# 0  https://www.autocarpro.in/news-international/f...
# 1  https://www.autocarpro.in/news-international/c...
# 2  https://www.autocarpro.in/news-international/s...
# 3  https://www.autocarpro.in/news-international/s...
# 4  https://www.autocarpro.in/news-international/c...

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')

# Initializing stopwords and lemmatizer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()


def preprocess_text(text):
    # Lowercase
    text = text.lower()

    # Remove special characters
    text = re.sub(r'\W+', ' ', text)

    # Tokenize
    words = word_tokenize(text)

    # Removing stopwords and lemmatizing
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]

    return ' '.join(words)

df['Cleaned_Content'] = df['Content'].apply(preprocess_text)

print(df[['Content', 'Cleaned_Content']].head())
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                              Content  \
# 0  The rear lamp is used in the Geely Auto Group’...
# 1  Continental ranked 265th in Time and Statista’...
# 2  Fourth annual Stellantis Supplier of the Year ...
# 3  Schaeffler has also announced the appointment ...
# 4  "The U.S. move has no factual basis, violates ...
#
#                                      Cleaned_Content
# 0  rear lamp used geely auto group new electric l...
# 1  continental ranked 265th time statista list 50...
# 2  fourth annual stellantis supplier year event l...
# 3  schaeffler also announced appointment vitesco ...
# 4  u move factual basis violates principle market...

# %%
df
# Out:
#            Date                                              Title  \
# 0     04-Sep-24        New 425hp Nissan Patrol debuts in Abu Dhabi
# 1     03-Sep-24  BMW calling back Mini Cooper SE electric model...
# 2     03-Sep-24  Hyundai Mobis reveals three-pronged strategy t...
# 3     02-Sep-24  BYD reaches agreement to acquire Hedin Mobilit...
# 4     31-Aug-24  Volkswagen explores use of 100% bio-based leat...
# ...         ...                                                ...
# 1003  19-Apr-23  Elektrobit to provide next-gen software archit...
# 1004  19-Apr-23  UK’s HVS unveils 40-tonne hydrogen truck with ...
# 1005  19-Apr-23  Nissan reveals Pathfinder concept SUV for Chin...
# 1006  18-Apr-23  Faurecia showcases breakthrough hydrogen solut...
# 1007  18-Apr-23  Nissan reveals electric Arizon concept SUV at ...
#
#                      Author  \
# 0     Autocar Pro News Desk
# 1     Autocar Pro News Desk
# 2     Autocar Pro News Desk
# 3     Autocar Pro News Desk
# 4     Autocar Pro News Desk
# ...                     ...
# 1003  Autocar Pro News Desk
# 1004  Autocar Pro News Desk
# 1005  Autocar Pro News Desk
# 1006  Autocar Pro News Desk
# 1007  Autocar Pro News Desk
#
#                                                    Tags  \
# 0                                                    []
# 1                                               ['BMW']
# 2            ['Hyundai Mobis', 'sustainable materials']
# 3                       ['BYD', 'Hedin Mobility Group']
# 4                                    ['Revoltech GmbH']
# ...                                                 ...
# 1003  ['Jaguar Land Rover', 'Elektrobit', 'EVA Conti...
# 1004  ['Hydrogen Vehicle Systems', 'Advanced Propuls...
# 1005                              ['Nissan Pathfinder']
# 1006  ['Symbio', 'Forvia', 'Faurecia', 'Faurecia Hyd...
# 1007            ['Nissan Arizon', 'Auto Shanghai 2023']
#
#                                                 Content  \
# 0     Seventh-generation sports bold new design, pow...
# 1     The company stated that issues in battery syst...
# 2     Next-generation core materials strategy to foc...
# 3     The transaction is subject to regulatory appro...
# 4     Volkswagen brand partners with Revoltech GmbH ...
# ...                                                 ...
# 1003  Elektrobit will partner Jaguar Land Rover to b...
# 1004  Reinvention of commercial vehicle design, aime...
# 1005  The Pathfinder Concept, like the all-electric ...
# 1006  While Containerised Hydrogen Solution can stor...
# 1007  Built on the CMF EV platform, the Arizon conce...
#
#                                                    Link  \
# 0     https://www.autocarpro.in/news-international/n...
# 1     https://www.autocarpro.in/news-international/b...
# 2     https://www.autocarpro.in/news-international/h...
# 3     https://www.autocarpro.in/news-international/b...
# 4     https://www.autocarpro.in/news-international/v...
# ...                                                 ...
# 1003  https://www.autocarpro.in/news-international/e...
# 1004  https://www.autocarpro.in/news-international/u...
# 1005  https://www.autocarpro.in/news-international/n...
# 1006  https://www.autocarpro.in/news-international/f...
# 1007  https://www.autocarpro.in/news-international/n...
#
#                                         Cleaned_Content
# 0     seventh generation sport bold new design power...
# 1     company stated issue battery system could resu...
# 2     next generation core material strategy focus s...
# 3     transaction subject regulatory approval closin...
# 4     volkswagen brand partner revoltech gmbh start ...
# ...                                                 ...
# 1003  elektrobit partner jaguar land rover build nex...
# 1004  reinvention commercial vehicle design aimed op...
# 1005  pathfinder concept like electric arizon suv co...
# 1006  containerised hydrogen solution store 1 ton us...
# 1007  built cmf ev platform arizon concept suv creat...
#
# [1008 rows x 7 columns]

# %%
#keywords for each category
keywords = {
    'financial': ['bankruptcies', 'payment trends', 'quarterly reports', 'financial', 'loss'],
    'geopolitical': ['civil unrest', 'conflict', 'tariffs', 'embargo', 'labor disputes', 'geopolitical'],
    'natural_disasters': ['fires', 'earthquake', 'weather', 'flood', 'storm', 'natural disaster'],
    'regulatory': ['import restrictions', 'export restrictions', 'anti-bribery', 'corruption', 'material compliance', 'regulatory']
}

# Function to check if any keyword exists in the text
def contains_keyword(text, keywords):
    return any(keyword in text for keyword in keywords)

df['Category_Match'] = df['Cleaned_Content'].apply(lambda x: any(contains_keyword(x, kw_list) for kw_list in keywords.values()))

# Filtering the rows that match any category keyword
filtered_df = df[df['Category_Match']]

print(filtered_df[['Date', 'Title', 'Cleaned_Content']].head())
# Out:
#            Date                                              Title  \
# 5   27 Sep 2024  EDAG Group opens cutting-edge lighting laborat...
# 10  26 Sep 2024  Antolin and PersiSkin develop plant-based alte...
# 18  20 Sep 2024  European auto industry calls for urgent action...
# 22  19 Sep 2024   EU car sales at three year low in August: Report
# 38  12 Sep 2024  Pathbreaking ‘massless’ energy storage promise...
#
#                                       Cleaned_Content
# 5   unique selling point new light laboratory desi...
# 10  persiskin auto composed high content persimmon...
# 18  european automobile manufacturer association c...
# 22  data pointed fourth continuous monthly drop ev...
# 38  world leading advance researcher chalmers univ...

# %%
filtered_df
# Out:
#               Date                                              Title  \
# 5      27 Sep 2024  EDAG Group opens cutting-edge lighting laborat...
# 10     26 Sep 2024  Antolin and PersiSkin develop plant-based alte...
# 18     20 Sep 2024  European auto industry calls for urgent action...
# 22     19 Sep 2024   EU car sales at three year low in August: Report
# 38     12 Sep 2024  Pathbreaking ‘massless’ energy storage promise...
# ...            ...                                                ...
# 1979  Mar 08, 2023  Epicor acquires cloud-based financial planning...
# 1997  Feb 22, 2023  Shifting geopolitical and economic dynamics pu...
# 2004  Feb 20, 2023    Serious Waste boosts growth with BigChange Tech
# 2005  Feb 20, 2023          Make UK National Manufacturing Conference
# 2007  Feb 16, 2023  What are the documents required for LCL shipment?
#
#                      Author  \
# 5     Autocar Pro News Desk
# 10    Autocar Pro News Desk
# 18    Autocar Pro News Desk
# 22    Autocar Pro News Desk
# 38    Autocar Pro News Desk
# ...                     ...
# 1979                    NaN
# 1997                    NaN
# 2004                    NaN
# 2005                    NaN
# 2007                    NaN
#
#                                                    Tags  Related Organzation  \
# 5     ['EDAG Group', 'Zero Prototype Lab', 'light la...                  NaN
# 10    ['Antolin', 'PersiSkin Auto', 'leather alterna...                  NaN
# 18    ['ACEA', 'BMW Group', 'Daimler Trucks', 'Toyot...                  NaN
# 22                                   ['European Union']                  NaN
# 38    ['Chalmers University of Technology', 'structu...                  NaN
# ...                                                 ...                  ...
# 1979           ['Planning', 'Manufacturing', 'Process']                  NaN
# 1997      ['Supply Chain', 'Critical Issues', 'Retail']                  NaN
# 2004                ['Transport Management', 'Process']                  NaN
# 2005  ['Exhibitions and Events', 'Manufacturing', 'P...                  NaN
# 2007                           ['Transport Management']                  NaN
#
#                                                 Content  \
# 5     The unique selling point of the new light labo...
# 10    PersiSkin Auto is composed of a high content o...
# 18    The European Automobile Manufacturers’ Associa...
# 22    The data pointed to the fourth continuous mont...
# 38    World-leading advance by researchers at the Ch...
# ...                                                 ...
# 1979   Epicor has acquired DSPanel, a global provide...
# 1997   By Craig Summers, Managing Director, Manhatta...
# 2004   Serious, a nationwide sewage, grease and wast...
# 2005   Make UK’s National Manufacturing Conference, ...
# 2007   By Robert Lewis, freelance writer. When it co...
#
#                                                    Link  \
# 5     https://www.autocarpro.in/news-international/e...
# 10    https://www.autocarpro.in/news-international/a...
# 18    https://www.autocarpro.in/news-international/e...
# 22    https://www.autocarpro.in/news-international/-...
# 38    https://www.autocarpro.in/news-international/p...
# ...                                                 ...
# 1979  https://www.logisticsit.com/articles/2023/03/0...
# 1997  https://www.logisticsit.com/articles/2023/02/2...
# 2004  https://www.logisticsit.com/articles/2023/02/2...
# 2005  https://www.logisticsit.com/articles/2023/02/2...
# 2007  https://www.logisticsit.com/articles/2023/02/1...
#
#                                         Cleaned_Content  Category_Match
# 5     unique selling point new light laboratory desi...            True
# 10    persiskin auto composed high content persimmon...            True
# 18    european automobile manufacturer association c...            True
# 22    data pointed fourth continuous monthly drop ev...            True
# 38    world leading advance researcher chalmers univ...            True
# ...                                                 ...             ...
# 1979  epicor acquired dspanel global provider cloud ...            True
# 1997  craig summer managing director manhattan assoc...            True
# 2004  serious nationwide sewage grease waste water m...            True
# 2005  make uk national manufacturing conference insp...            True
# 2007  robert lewis freelance writer come internation...            True
#
# [448 rows x 9 columns]

# %% [markdown]
# Tf-idf vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=1000)

tfidf_matrix = tfidf_vectorizer.fit_transform(filtered_df['Cleaned_Content'])

print(tfidf_matrix.shape)
# Out:
# (448, 1000)

# %% [markdown]
# LSI

# %%
from sklearn.decomposition import TruncatedSVD

# Initialize TruncatedSVD (LSI)
lsi_model = TruncatedSVD(n_components=5, random_state=42)


lsi_topics = lsi_model.fit_transform(tfidf_matrix)

#the resulting topic vectors
print(lsi_topics[:5])

# the top terms per topic
terms = tfidf_vectorizer.get_feature_names_out()
for i, component in enumerate(lsi_model.components_):
    terms_in_topic = [terms[i] for i in component.argsort()[:-10 - 1:-1]]
    print(f"Topic {i}: {terms_in_topic}")
# Out:
# [[ 0.2944796  -0.21142586  0.00251383  0.14628768  0.04723579]
#  [ 0.22083448 -0.1674205   0.04541624  0.05893141  0.03965006]
#  [ 0.27944435 -0.33932766  0.17652719 -0.03765133  0.02977873]
#  [ 0.19081682 -0.2643255   0.06691578 -0.08150451  0.02620036]
#  [ 0.26134504 -0.33038798  0.11943915  0.11877009  0.01530619]]
# Topic 0: ['chain', 'supply', 'business', 'data', 'company', 'customer', 'ai', 'technology', 'uk', 'system']
# Topic 1: ['chain', 'supply', 'ai', 'data', 'disruption', 'planning', 'organisation', 'visibility', 'supplier', 'business']
# Topic 2: ['chain', 'supply', 'vehicle', 'battery', 'electric', 'ev', 'disruption', 'supplier', 'global', 'truck']
# Topic 3: ['ai', 'system', 'data', 'vehicle', 'solution', 'management', 'battery', 'technology', 'safety', 'driver']
# Topic 4: ['retailer', 'customer', 'delivery', 'return', 'retail', 'consumer', 'brand', 'product', 'store', 'chain']

# %% [markdown]
# LDA

# %%
import gensim
from gensim import corpora

texts = [content.split() for content in filtered_df['Cleaned_Content']]

dictionary = corpora.Dictionary(texts)

corpus = [dictionary.doc2bow(text) for text in texts]

# Applying LDA
lda_model = gensim.models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=5, random_state=42, passes=10)

# the top terms in each topic
topics = lda_model.print_topics(num_words=10)
for topic in topics:
    print(topic)
# Out:
# (0, '0.007*"new" + 0.006*"company" + 0.006*"vehicle" + 0.005*"customer" + 0.005*"market" + 0.005*"technology" + 0.005*"solution" + 0.005*"year" + 0.004*"business" + 0.004*"also"')
# (1, '0.006*"business" + 0.006*"vehicle" + 0.006*"new" + 0.005*"battery" + 0.005*"year" + 0.005*"technology" + 0.005*"industry" + 0.004*"material" + 0.004*"also" + 0.004*"company"')
# (2, '0.009*"system" + 0.007*"vehicle" + 0.005*"year" + 0.004*"data" + 0.004*"time" + 0.004*"also" + 0.004*"battery" + 0.004*"car" + 0.003*"new" + 0.003*"percent"')
# (3, '0.013*"chain" + 0.013*"supply" + 0.010*"data" + 0.009*"business" + 0.007*"company" + 0.006*"ai" + 0.006*"time" + 0.006*"customer" + 0.006*"technology" + 0.005*"management"')
# (4, '0.006*"business" + 0.005*"employee" + 0.005*"year" + 0.004*"container" + 0.004*"threat" + 0.004*"cost" + 0.004*"2023" + 0.004*"also" + 0.004*"uk" + 0.004*"attack"')

# %%
from gensim.models import CoherenceModel

# Compute Coherence Score for LDA
coherence_model_lda = CoherenceModel(model=lda_model, texts=[doc.split() for doc in filtered_df['Cleaned_Content']], dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print(f'LDA Coherence Score: {coherence_lda}')
# Out:
# LDA Coherence Score: 0.32297143283829327

# %%
# !pip install bertopic sentence-transformers pandas
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.4-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.39-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.26.4)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.6)
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.0+cu121)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (9.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Downloading bertopic-0.16.4-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 14.4 MB/s eta 0:00:00
# Downloading hdbscan-0.8.39-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 104.2 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 8.7 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: pynndescent, hdbscan, umap-learn, bertopic
# Successfully installed bertopic-0.16.4 hdbscan-0.8.39 pynndescent-0.5.13 umap-learn-0.5.7

# %%
import nltk

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Check current NLTK data paths
print("Current NLTK data paths:", nltk.data.path)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Current NLTK data paths: ['/root/nltk_data', '/usr/nltk_data', '/usr/share/nltk_data', '/usr/lib/nltk_data', '/usr/share/nltk_data', '/usr/local/share/nltk_data', '/usr/lib/nltk_data', '/usr/local/lib/nltk_data']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string

# Preprocessing function
def preprocess_text(text):
    # Tokenization
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.lower() not in stop_words]

    # Remove punctuation
    tokens = [word for word in tokens if word not in string.punctuation]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    # Join tokens back into a single string
    return ' '.join(tokens)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
# Assuming your dataset is in a CSV file named 'articles.csv'
df = pd.read_csv('/content/newsdata.csv')

# Extract the content column for topic modeling
docs1 = df['Content'].tolist()

# Define seed keywords
seed_keywords = [
    ["bankruptcy", "financial", "payment", "trend", "report"],  # Financial
    ["civil unrest", "geopolitical", "tariff", "conflict", "currency"],  # Geopolitical
    ["fire", "earthquake", "weather", "disaster"],  # Natural disasters
    ["import", "export", "corruption", "compliance", "regulation"]  # Regulatory
]

# %%
df
# Out:
#               Date                                              Title  \
# 0      28 Sep 2024  Forvia Hella begins making RGB LED rear combin...
# 1      28 Sep 2024  Continental named among top 500 sustainable co...
# 2      28 Sep 2024  Stellantis honours 68 global and regional supp...
# 3      27 Sep 2024  Schaeffler names new CFO ahead of expected mer...
# 4      27 Sep 2024  China requests US to stop 'unreasonable suppre...
# ...            ...                                                ...
# 2003  Feb 21, 2023  No more sleepless nights for IT Director at wh...
# 2004  Feb 20, 2023    Serious Waste boosts growth with BigChange Tech
# 2005  Feb 20, 2023          Make UK National Manufacturing Conference
# 2006  Feb 20, 2023  AR 'Magic Mirror' from Vyking launches for UK ...
# 2007  Feb 16, 2023  What are the documents required for LCL shipment?
#
#                      Author  \
# 0     Autocar Pro News Desk
# 1     Autocar Pro News Desk
# 2     Autocar Pro News Desk
# 3     Autocar Pro News Desk
# 4     Autocar Pro News Desk
# ...                     ...
# 2003                    NaN
# 2004                    NaN
# 2005                    NaN
# 2006                    NaN
# 2007                    NaN
#
#                                                    Tags  Related Organzation  \
# 0     ['Lynk & Co', 'Geely Auto', 'Forvia Hella', 'R...                  NaN
# 1     ['Continental', 'Continental Tires', "world's ...                  NaN
# 2     ['Stellantis', 'Stellantis Supplier of the Yea...                  NaN
# 3                ['Vitesco Technologies', 'Schaeffler']                  NaN
# 4                                                    []                  NaN
# ...                                                 ...                  ...
# 2003                       ['Manufacturing', 'Process']                  NaN
# 2004                ['Transport Management', 'Process']                  NaN
# 2005  ['Exhibitions and Events', 'Manufacturing', 'P...                  NaN
# 2006                          ['Datacapture', 'Retail']                  NaN
# 2007                           ['Transport Management']                  NaN
#
#                                                 Content  \
# 0     The rear lamp is used in the Geely Auto Group’...
# 1     Continental ranked 265th in Time and Statista’...
# 2     Fourth annual Stellantis Supplier of the Year ...
# 3     Schaeffler has also announced the appointment ...
# 4     "The U.S. move has no factual basis, violates ...
# ...                                                 ...
# 2003   moveero is a global manufacturer of wheels fo...
# 2004   Serious, a nationwide sewage, grease and wast...
# 2005   Make UK’s National Manufacturing Conference, ...
# 2006   Virtual try-on startup Vyking.io has launched...
# 2007   By Robert Lewis, freelance writer. When it co...
#
#                                                    Link
# 0     https://www.autocarpro.in/news-international/f...
# 1     https://www.autocarpro.in/news-international/c...
# 2     https://www.autocarpro.in/news-international/s...
# 3     https://www.autocarpro.in/news-international/s...
# 4     https://www.autocarpro.in/news-international/c...
# ...                                                 ...
# 2003  https://www.logisticsit.com/articles/2023/02/2...
# 2004  https://www.logisticsit.com/articles/2023/02/2...
# 2005  https://www.logisticsit.com/articles/2023/02/2...
# 2006  https://www.logisticsit.com/articles/2023/02/2...
# 2007  https://www.logisticsit.com/articles/2023/02/1...
#
# [2008 rows x 7 columns]

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import nltk
nltk.download('wordnet')

# Continue with the rest of your code
lemmatizer = WordNetLemmatizer()

# Tokenize the text in the 'Content' column
df['Tokens'] = df['Content'].apply(word_tokenize)

print(df['Tokens'])
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 0       [The, rear, lamp, is, used, in, the, Geely, Au...
# 1       [Continental, ranked, 265th, in, Time, and, St...
# 2       [Fourth, annual, Stellantis, Supplier, of, the...
# 3       [Schaeffler, has, also, announced, the, appoin...
# 4       [``, The, U.S., move, has, no, factual, basis,...
#                               ...
# 2003    [moveero, is, a, global, manufacturer, of, whe...
# 2004    [Serious, ,, a, nationwide, sewage, ,, grease,...
# 2005    [Make, UK, ’, s, National, Manufacturing, Conf...
# 2006    [Virtual, try-on, startup, Vyking.io, has, lau...
# 2007    [By, Robert, Lewis, ,, freelance, writer, ., W...
# Name: Tokens, Length: 2008, dtype: object

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Preprocessing the documents using defined function
docs1 = [preprocess_text(doc) for doc in docs1]

# Creating sentence embeddings using a pretrained Sentence Transformer model
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = sentence_model.encode(docs1, show_progress_bar=True)

# Creating a custom vectorizer with seed keywords
vectorizer_model = CountVectorizer(vocabulary=sum(seed_keywords, []))

# Creating the BERTopic model with the custom vectorizer
topic_model = BERTopic(vectorizer_model=vectorizer_model)

# Fitting the BERTopic model using the preprocessed documents and embeddings
topics, probs = topic_model.fit_transform(docs1, embeddings)

# Adding topics to the original dataframe
df['topic'] = topics

#top words for each topic
topic_info = topic_model.vectorizer_model.get_feature_names_out()
topics = topic_model.get_topics()

for topic_id, words in topics.items():
    # Sorting words by their scores in descending order and get the top 10 words
    top_words = [word for word, score in sorted(words, key=lambda item: item[1], reverse=True)[:10]]
    print(f"Topic {topic_id}: {', '.join(top_words)}")

# Saving the updated dataframe with topics
df.to_csv('articles_with_topics.csv', index=False)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/63 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/bertopic/vectorizers/_ctfidf.py:82: RuntimeWarning: divide by zero encountered in divide
#   idf = np.log((avg_nr_samples / df) + 1)
# Topic -1: payment, trend, compliance, financial, regulation, geopolitical, report, export, fire, weather
# Topic 0: fire, conflict, export, regulation, weather, financial, geopolitical, trend, report, compliance
# Topic 1: currency, payment, trend, tariff, report, financial, regulation, weather, compliance, export
# Topic 2: export, financial, weather, disaster, geopolitical, fire, import, regulation, report, trend
# Topic 3: regulation, trend, report, compliance, geopolitical, financial, , , ,
# Topic 4: tariff, export, import, earthquake, report, geopolitical, trend, regulation, disaster, fire
# Topic 5: regulation, weather, financial, compliance, trend, report, , , ,
# Topic 6: compliance, weather, fire, report, trend, financial, regulation, , ,
# Topic 7: disaster, report, currency, trend, financial, compliance, conflict, geopolitical, regulation, payment
# Topic 8: trend, regulation, compliance, report, weather, financial, , , ,
# Topic 9: geopolitical, weather, import, regulation, conflict, export, trend, compliance, disaster, report
# Topic 10: report, disaster, compliance, trend, export, import, geopolitical, financial, regulation,
# Topic 11: export, report, geopolitical, financial, trend, payment, regulation, , ,
# Topic 12: import, export, regulation, weather, compliance, trend, report, , ,
# Topic 13: payment, conflict, import, currency, export, fire, report, compliance, financial, regulation
# Topic 14: compliance, corruption, report, financial, fire, regulation, trend, conflict, import, geopolitical
# Topic 15: weather, report, regulation, financial, trend, , , , ,
# Topic 16: import, export, compliance, weather, financial, regulation, trend, report, ,
# Topic 17: import, tariff, disaster, geopolitical, report, earthquake, conflict, regulation, financial, compliance
# Topic 18: tariff, export, financial, report, , , , , ,
# Topic 19: regulation, weather, financial, report, , , , , ,
# Topic 20: financial, geopolitical, trend, report, payment, compliance, , , ,
# Topic 21: weather, compliance, , , , , , , ,
# Topic 22: financial, report, fire, compliance, payment, regulation, , , ,
# Topic 23: financial, report, trend, , , , , , ,
# Topic 24: weather, payment, regulation, compliance, trend, , , , ,
# Topic 25: disaster, conflict, report, compliance, , , , , ,
# Topic 26: regulation, export, trend, , , , , , ,
# Topic 27: disaster, export, import, geopolitical, regulation, trend, , , ,
# Topic 28: conflict, financial, geopolitical, , , , , , ,
# Topic 29: payment, financial, , , , , , , ,
# Topic 30: export, financial, compliance, report, , , , , ,
# Topic 31: regulation, trend, , , , , , , ,
# Topic 32: tariff, import, payment, export, report, , , , ,
# Topic 33: trend, report, , , , , , , ,
# Topic 34: export, financial, trend, report, , , , , ,
# Topic 35: weather, trend, , , , , , , ,

# %% [markdown]
# Intertopic distance map

# %%
import matplotlib.pyplot as plt

# Visualize the topics
fig = topic_model.visualize_topics()
fig.show()

# Save the visualization to a file
fig.write_html("topics_visualization.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="530cd8fa-8541-48c0-b267-ff37d3e3bbdb" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("530cd8fa-8541-48c0-b267-ff37d3e3bbdb")) {                    Plotly.newPlot(                        "530cd8fa-8541-48c0-b267-ff37d3e3bbdb",                        [{"customdata":[[0,"fire | conflict | export | regulation | weather",92],[1,"currency | payment | trend | tariff | report",80],[2,"export | financial | weather | disaster | geopolitical",68],[3,"regulation | trend | report | compliance | geopolitical",57],[4,"tariff | export | import | earthquake | report",55],[5,"regulation | weather | financial | compliance | trend",51],[6,"compliance | weather | fire | report | trend",49],[7,"disaster | report | currency | trend | financial",48],[8,"trend | regulation | compliance | report | weather",47],[9,"geopolitical | weather | import | regulation | conflict",46],[10,"report | disaster | compliance | trend | export",43],[11,"export | report | geopolitical | financial | trend",42],[12,"import | export | regulation | weather | compliance",41],[13,"payment | conflict | import | currency | export",38],[14,"compliance | corruption | report | financial | fire",34],[15,"weather | report | regulation | financial | trend",33],[16,"import | export | compliance | weather | financial",31],[17,"import | tariff | disaster | geopolitical | report",31],[18,"tariff | export | financial | report | ",31],[19,"regulation | weather | financial | report | ",29],[20,"financial | geopolitical | trend | report | payment",28],[21,"weather | compliance |  |  | ",28],[22,"financial | report | fire | compliance | payment",25],[23,"financial | report | trend |  | ",23],[24,"weather | payment | regulation | compliance | trend",23],[25,"disaster | conflict | report | compliance | ",23],[26,"regulation | export | trend |  | ",22],[27,"disaster | export | import | geopolitical | regulation",20],[28,"conflict | financial | geopolitical |  | ",19],[29,"payment | financial |  |  | ",17],[30,"export | financial | compliance | report | ",14],[31,"regulation | trend |  |  | ",14],[32,"tariff | import | payment | export | report",13],[33,"trend | report |  |  | ",12],[34,"export | financial | trend | report | ",11],[35,"weather | trend |  |  | ",10]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[92,80,68,57,55,51,49,48,47,46,43,42,41,38,34,33,31,31,31,29,28,28,25,23,23,23,22,20,19,17,14,14,13,12,11,10],"sizemode":"area","sizeref":0.0575,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-5.1324396,14.044097,4.851189,13.558226,5.3317223,-4.900736,9.79134,13.334751,9.51541,1.1283469,13.44837,13.230335,6.002707,13.56188,13.335714,14.126622,13.348041,5.424961,5.678869,5.7497025,1.1085949,-4.7848077,13.124168,4.937571,-5.3061314,13.783332,4.879041,6.2986903,5.280623,5.18486,5.4809895,9.68953,5.2308574,13.085468,4.843001,9.385992],"xaxis":"x","y":[2.3855689,-0.40556237,10.513862,-1.4583781,8.89318,2.1486123,15.339981,-2.2252684,15.064595,-11.759878,-1.5988325,0.74004394,9.754807,0.2171472,-1.9247617,-0.32165733,0.55532545,-5.2987905,8.677552,-5.62212,-11.783682,2.0315602,0.8779979,9.514939,2.5597663,-0.47499812,9.808002,9.894195,-5.15474,9.682904,-5.3552065,15.2383795,9.009523,-1.5389603,10.624316,14.935049],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36, ...

# %% [markdown]
# Adjusting/Fine tuning the BertTopic model

# %%
 # Printing top words for each topic to evaluate topic quality
topic_info = topic_model.get_topic_info()
print(topic_info)  # Display the number of topics and their sizes

#adjusting the BERTopic model
topic_model = BERTopic(vectorizer_model=vectorizer_model, n_gram_range=(1, 2), min_topic_size=10)

# Re-fitting the model with adjust parameters
topics, probs = topic_model.fit_transform(docs1, embeddings)

# Re-check the topic quality after adjustments
print(topic_model.get_topic_info())
# Out:
#     Topic  Count                                       Name  \
# 0      -1    760      -1_payment_trend_compliance_financial
# 1       0     92          0_fire_conflict_export_regulation
# 2       1     80            1_currency_payment_trend_tariff
# 3       2     68        2_export_financial_weather_disaster
# 4       3     57       3_regulation_trend_report_compliance
# 5       4     55          4_tariff_export_import_earthquake
# 6       5     51  5_regulation_weather_financial_compliance
# 7       6     49           6_compliance_weather_fire_report
# 8       7     48           7_disaster_report_currency_trend
# 9       8     47       8_trend_regulation_compliance_report
# 10      9     46   9_geopolitical_weather_import_regulation
# 11     10     43        10_report_disaster_compliance_trend
# 12     11     42    11_export_report_geopolitical_financial
# 13     12     41        12_import_export_regulation_weather
# 14     13     38        13_payment_conflict_import_currency
# 15     14     34  14_compliance_corruption_report_financial
# 16     15     33     15_weather_report_regulation_financial
# 17     16     31        16_import_export_compliance_weather
# 18     17     31     17_import_tariff_disaster_geopolitical
# 19     18     31          18_tariff_export_financial_report
# 20     19     29     19_regulation_weather_financial_report
# 21     20     28     20_financial_geopolitical_trend_report
# 22     21     28                    21_weather_compliance__
# 23     22     25        22_financial_report_fire_compliance
# 24     23     23                 23_financial_report_trend_
# 25     24     23   24_weather_payment_regulation_compliance
# 26     25     23     25_disaster_conflict_report_compliance
# 27     26     22                26_regulation_export_trend_
# 28     27     20     27_disaster_export_import_geopolitical
# 29     28     19        28_conflict_financial_geopolitical_
# 30     29     17                     29_payment_financial__
# 31     30     14      30_export_financial_compliance_report
# 32     31     14                      31_regulation_trend__
# 33     32     13            32_tariff_import_payment_export
# 34     33     12                          33_trend_report__
# 35     34     11           34_export_financial_trend_report
# 36     35     10                         35_weather_trend__
#
#                                        Representation  \
# 0   [payment, trend, compliance, financial, regula...
# 1   [fire, conflict, export, regulation, weather, ...
# 2   [currency, payment, trend, tariff, report, fin...
# 3   [export, financial, weather, disaster, geopoli...
# 4   [regulation, trend, report, compliance, geopol...
# 5   [tariff, export, import, earthquake, report, g...
# 6   [regulation, weather, financial, compliance, t...
# 7   [compliance, weather, fire, report, trend, fin...
# 8   [disaster, report, currency, trend, financial,...
# 9   [trend, regulation, compliance, report, weathe...
# 10  [geopolitical, weather, import, regulation, co...
# 11  [report, disaster, compliance, trend, export, ...
# 12  [export, report, geopolitical, financial, tren...
# 13  [import, export, regulation, weather, complian...
# 14  [payment, conflict, import, currency, export, ...
# 15  [compliance, corruption, report, financial, fi...
# 16  [weather, report, regulation, financial, trend...
# 17  [import, export, compliance, weather, financia...
# 18  [import, tariff, disaster, geopolitical, repor...
# 19    [tariff, export, financial, report, , , , , , ]
# 20  [regulation, weather, financial, report, , , ,...
# 21  [financial, geopolitical, trend, report, payme...
# 22              [weather, compliance, , , , , , , , ]
# 23  [financial, report, fire, compliance, payment,...
# 24           [financial, report, trend, , , , , , , ]
# 25  [weather, payment, regulation, compliance, tre...
# 26  [disaster, conflict, report, compliance, , , ,...
# 27          [regulation, export, trend, , , , , , , ]
# 28  [disaster, export, import, geopolitical, regul...
# 29  [conflict, financial, geopolitical, , , , , , , ]
# 30               [payment, financial, , , , , , , , ]
# 31  [export, financial, compliance, report, , , , ...
# 32                [regulation, trend, , , , , , , , ]
# 33  [tariff, import, payment, export, report, , , ...
# 34                    [trend, report, , , , , , , , ]
# 35     [export, financial, trend, report, , , , , , ]
# 36                   [weather, trend, , , , , , , , ]
#
#                                   Representative_Docs
# 0   [Today consumer across UK facing cost living c...
# 1   [company stated issue battery system could res...
# 2   [Applause provider testing digital quality sol...
# 3   [New Kia K3 sport bold design spacious interio...
# 4   [Business technology solution provider Brother...
# 5   [Combustion car weighing 1,600kg EVs weighing ...
# 6   [First VDL Groep truck using Toyota hydrogen f...
# 7   [Operating Mercedes-Benz franchise 20 year Int...
# 8   [Sophos released annual 2024 Sophos Threat Rep...
# 9   [Geoffrey Bouquot previously Valeo Group CTO s...
# 10  [Research Ivalua Cloud Spend Management soluti...
# 11  [Rockwell Automation Inc announced result 9th ...
# 12  [Commenting latest CIPS UK Manufacturing Purch...
# 13  [Introduced Intermot 1998 Suzuki Hayabusa perf...
# 14  [Transporeon Trimble Company expanded transpor...
# 15  [new report global law firm White Case LLP Ris...
# 16  [Simply Lunch producer ‘ food-to-go ’ using Po...
# 17  [Dan Culverhouse UK managing director Customs ...
# 18  [climate change apparent ever ACO Technologies...
# 19  [Volvo Trucks delivered eight heavy electric t...
# 20  [Key sustainability target NGP2030 include red...
# 21  [Stephen Dombroski Director Consumer Markets Q...
# 22  [Nano Cooling Film lower interior temperature ...
# 23  [Businesses manufacturing sector take empathet...
# 24  [David Woolley 35 year ’ experience across aut...
# 25  [2022 Hyundai released CGI video automated cha...
# 26  [Manhattan Associates Inc. global leader suppl...
# 27  [business scope cover R production sale airbag...
# 28  [Indian tyre major us platform Latin Tyre Auto...
# 29  [pressure investor said original offer 91 euro...
# 30  [Eighth annual event held Betim Brazil saw 99 ...
# 31  [Kirkhorn company veteran 13 year remain Tesla...
# 32  [event accident driver airbag deploys top side...
# 33  [White House said placing stringent curb Chine...
# 34  [Jungheinrich premiered latest mobile robot so...
# 35  [first model starting Karoq Kodiaq imported Eu...
# 36  [rear lamp used Geely Auto Group ’ new all-ele...
# /usr/local/lib/python3.10/dist-packages/bertopic/vectorizers/_ctfidf.py:82: RuntimeWarning:
#
# divide by zero encountered in divide
#     Topic  Count                                       Name  \
# 0      -1    762      -1_payment_trend_financial_compliance
# 1       0    127       0_fire_financial_export_geopolitical
# 2       1     82            1_currency_payment_trend_tariff
# 3       2     60       2_regulation_trend_report_compliance
# 4       3     57          3_trend_regulation_weather_report
# 5       4     55         4_report_compliance_disaster_trend
# 6       5     47  5_regulation_weather_financial_compliance
# 7       6     47           6_disaster_report_currency_trend
# 8       7     46          7_fire_conflict_export_regulation
# 9       8     46           8_compliance_weather_fire_report
# 10      9     44     9_export_report_geopolitical_financial
# 11     10     37        10_import_export_regulation_weather
# 12     11     34     11_import_compliance_weather_financial
# 13     12     33        12_payment_conflict_currency_import
# 14     13     31          13_tariff_export_financial_report
# 15     14     31      14_geopolitical_import_export_weather
# 16     15     31       15_compliance_corruption_report_fire
# 17     16     31    16_compliance_geopolitical_trend_report
# 18     17     29           17_import_tariff_disaster_report
# 19     18     28     18_regulation_weather_financial_report
# 20     19     28               19_payment_financial_report_
# 21     20     25        20_fire_financial_report_compliance
# 22     21     24                    21_weather_compliance__
# 23     22     23        22_tariff_geopolitical_trend_import
# 24     23     23   23_disaster_conflict_geopolitical_report
# 25     24     22                24_regulation_export_trend_
# 26     25     20                      25_fire_trend_report_
# 27     26     20     26_disaster_export_import_geopolitical
# 28     27     18          27_trend_financial_report_payment
# 29     28     18        28_weather_payment_regulation_trend
# 30     29     16                          29_trend_report__
# 31     30     15                30_financial_geopolitical__
# 32     31     14                      31_regulation_trend__
# 33     32     13      32_export_financial_compliance_report
# 34     33     13             33_export_tariff_import_report
# 35     34     13         34_tariff_export_report_regulation
# 36     35     12                            35_fire_trend__
# 37     36     12                         36_weather_trend__
# 38     37     11           37_export_financial_trend_report
# 39     38     10                   38_tariff_import_export_
#
#                                        Representation  \
# 0   [payment, trend, financial, compliance, regula...
# 1   [fire, financial, export, geopolitical, report...
# 2   [currency, payment, trend, tariff, report, fin...
# 3   [regulation, trend, report, compliance, geopol...
# 4   [trend, regulation, weather, report, complianc...
# 5   [report, compliance, disaster, trend, export, ...
# 6   [regulation, weather, financial, compliance, t...
# 7   [disaster, report, currency, trend, financial,...
# 8   [fire, conflict, export, regulation, geopoliti...
# 9   [compliance, weather, fire, report, trend, fin...
# 10  [export, report, geopolitical, financial, tren...
# 11  [import, export, regulation, weather, complian...
# 12  [import, compliance, weather, financial, regul...
# 13  [payment, conflict, currency, import, report, ...
# 14    [tariff, export, financial, report, , , , , , ]
# 15  [geopolitical, import, export, weather, regula...
# 16  [compliance, corruption, report, fire, regulat...
# 17  [compliance, geopolitical, trend, report, regu...
# 18  [import, tariff, disaster, report, regulation,...
# 19  [regulation, weather, financial, report, , , ,...
# 20         [payment, financial, report, , , , , , , ]
# 21  [fire, financial, report, compliance, regulati...
# 22              [weather, compliance, , , , , , , , ]
# 23  [tariff, geopolitical, trend, import, export, ...
# 24  [disaster, conflict, geopolitical, report, fin...
# 25          [regulation, export, trend, , , , , , , ]
# 26                [fire, trend, report, , , , , , , ]
# 27  [disaster, export, import, geopolitical, regul...
# 28  [trend, financial, report, payment, compliance...
# 29  [weather, payment, regulation, trend, , , , , , ]
# 30                    [trend, report, , , , , , , , ]
# 31          [financial, geopolitical, , , , , , , , ]
# 32                [regulation, trend, , , , , , , , ]
# 33  [export, financial, compliance, report, , , , ...
# 34       [export, tariff, import, report, , , , , , ]
# 35  [tariff, export, report, regulation, financial...
# 36                      [fire, trend, , , , , , , , ]
# 37                   [weather, trend, , , , , , , , ]
# 38     [export, financial, trend, report, , , , , , ]
# 39             [tariff, import, export, , , , , , , ]
#
#                                   Representative_Docs
# 0   [Companies still consider sustainability le im...
# 1   [First vehicle delivery British electric two-w...
# 2   [Applause provider testing digital quality sol...
# 3   [Raymond Cheng Managing Director WayKen Rapid ...
# 4   [Marquardt ’ DemoCar 2.0 showcase vehicle inte...
# 5   [Manufacturers increasingly incorporating augm...
# 6   [transforming vehicle packaging compact engine...
# 7   [Sophos released annual 2024 Sophos Threat Rep...
# 8   [Leading Indian battery maker setting gigafact...
# 9   [VisionTrack extending longstanding partnershi...
# 10  [Commenting latest CIPS UK Manufacturing Purch...
# 11  [Introduced Intermot 1998 Suzuki Hayabusa perf...
# 12  [Logistics UK announced return Transport Manag...
# 13  [Transporeon Trimble Company expanded transpor...
# 14  [Volvo Trucks delivered eight heavy electric t...
# 15  [International procurement supply chain manage...
# 16  [Many industrial company across UK exploring b...
# 17  [part ongoing transformation journey contract ...
# 18  [climate change apparent ever ACO Technologies...
# 19  [Key sustainability target NGP2030 include red...
# 20  [New facility Maranello house production ICE h...
# 21  [Businesses manufacturing sector take empathet...
# 22  [Integrated system fewer part smaller size wei...
# 23  [Combustion car weighing 1,600kg EVs weighing ...
# 24  [Fredrik Lindhagen product director nShift Ong...
# 25  [business scope cover R production sale airbag...
# 26  [efficient cell packaging reduced battery weig...
# 27  [Indian tyre major us platform Latin Tyre Auto...
# 28  [Holger Clasing Head Strategy Practice 4flow c...
# 29  [Ionna joint venture BMW GM Honda Hyundai Kia ...
# 30  [CKF ’ latest standard robotic palletising sys...
# 31  [pressure investor said original offer 91 euro...
# 32  [event accident driver airbag deploys top side...
# 33  [Muppasani replace Carl Smiley Stellantis toda...
# 34  [six-millionth vehicle named Bao 5 super-hybri...
# 35  [Prime minister announces five-year delay non-...
# 36  [April 2013 two OEMs signed strategic partners...
# 37  [rear lamp used Geely Auto Group ’ new all-ele...
# 38  [first model starting Karoq Kodiaq imported Eu...
# 39  [mark first time American company 's car made ...

# %% [markdown]
# Defining class labels

# %%
# Define the refined topic labels
topic_labels = {
    -1: "Finance,Geopolitical, Natural Disasters, Regulatory",
    0: "Finance, Regulatory, Geopolitical",
    1: "Natural Disasters, Geopolitical, Regulatory",
    2: "Finance, Geopolitical, Regulatory",
    3: "Finance, Natural Disasters, Geopolitical",
    4: "Geopolitical, Natural Disasters, Regulatory",
    5: "Regulatory, Finance, Natural Disasters",
    6: "Natural Disasters, Finance, Regulatory",
    7: "Natural Disasters, Finance, Geopolitical, Regulatory",
    8: "Regulatory, Finance, Natural Disasters",
    9: "Geopolitical, Natural Disasters, Regulatory",
    10: "Natural Disasters, Geopolitical, Finance, Regulatory",
    11: "Geopolitical, Finance, Regulatory",
    12: "Regulatory, Geopolitical, Natural Disasters",
    13: "Geopolitical, Finance, Regulatory, Natural Disasters",
    14: "Finance, Geopolitical, Regulatory",
    15: "Natural Disasters, Finance, Regulatory",
    16: "Regulatory, Geopolitical, Finance, Natural Disasters",
    17: "Geopolitical, Natural Disasters, Regulatory",
    18: "Geopolitical, Finance",
    19: "Regulatory, Finance, Natural Disasters",
    20: "Geopolitical, Finance, Regulatory",
    21: "Natural Disasters, Regulatory",
    22: "Finance, Regulatory, Natural Disasters",
    23: "Finance",
    24: "Natural Disasters, Regulatory, Finance",
    25: "Natural Disasters, Geopolitical, Regulatory",
    26: "Regulatory, Geopolitical",
    27: "Geopolitical, Regulatory, Natural Disasters",
    28: "Geopolitical, Finance",
    29: "Finance",
    30: "Finance, Geopolitical, Regulatory",
    31: "Natural Disasters, Finance",
    32: "Natural Disasters",
    33: "Finance",
    34: "Geopolitical, Regulatory",
    35: "Natural Disasters, Finance"
}

# Applying the refined labels to dataframe
df['topic_label'] = df['topic'].map(topic_labels)

# Printing the relevant columns
print(df[['Content', 'topic', 'topic_label']])
# Out:
#                                                 Content  topic  \
# 0     The rear lamp is used in the Geely Auto Group’...     35
# 1     Continental ranked 265th in Time and Statista’...     27
# 2     Fourth annual Stellantis Supplier of the Year ...     29
# 3     Schaeffler has also announced the appointment ...     28
# 4     "The U.S. move has no factual basis, violates ...     32
# ...                                                 ...    ...
# 2003   moveero is a global manufacturer of wheels fo...      7
# 2004   Serious, a nationwide sewage, grease and wast...     -1
# 2005   Make UK’s National Manufacturing Conference, ...     11
# 2006   Virtual try-on startup Vyking.io has launched...      1
# 2007   By Robert Lewis, freelance writer. When it co...     -1
#
#                                             topic_label
# 0                            Natural Disasters, Finance
# 1           Geopolitical, Regulatory, Natural Disasters
# 2                                               Finance
# 3                                 Geopolitical, Finance
# 4                                     Natural Disasters
# ...                                                 ...
# 2003  Natural Disasters, Finance, Geopolitical, Regu...
# 2004  Finance,Geopolitical, Natural Disasters, Regul...
# 2005                  Geopolitical, Finance, Regulatory
# 2006        Natural Disasters, Geopolitical, Regulatory
# 2007  Finance,Geopolitical, Natural Disasters, Regul...
#
# [2008 rows x 3 columns]

# %%
df['probability'] = probs  # Adds probability scores for each topic
print(df[['Content', 'topic', 'topic_label', 'probability']])
# Out:
#                                                 Content  topic  \
# 0     The rear lamp is used in the Geely Auto Group’...     35
# 1     Continental ranked 265th in Time and Statista’...     27
# 2     Fourth annual Stellantis Supplier of the Year ...     29
# 3     Schaeffler has also announced the appointment ...     28
# 4     "The U.S. move has no factual basis, violates ...     32
# ...                                                 ...    ...
# 2003   moveero is a global manufacturer of wheels fo...      7
# 2004   Serious, a nationwide sewage, grease and wast...     -1
# 2005   Make UK’s National Manufacturing Conference, ...     11
# 2006   Virtual try-on startup Vyking.io has launched...      1
# 2007   By Robert Lewis, freelance writer. When it co...     -1
#
#                                             topic_label  probability
# 0                            Natural Disasters, Finance     1.000000
# 1           Geopolitical, Regulatory, Natural Disasters     1.000000
# 2                                               Finance     1.000000
# 3                                 Geopolitical, Finance     1.000000
# 4                                     Natural Disasters     1.000000
# ...                                                 ...          ...
# 2003  Natural Disasters, Finance, Geopolitical, Regu...     0.589250
# 2004  Finance,Geopolitical, Natural Disasters, Regul...     0.000000
# 2005                  Geopolitical, Finance, Regulatory     0.993273
# 2006        Natural Disasters, Geopolitical, Regulatory     0.554038
# 2007  Finance,Geopolitical, Natural Disasters, Regul...     0.000000
#
# [2008 rows x 4 columns]

# %%
df.to_csv('classified_documents_with_topics.csv', index=False)

# %% [markdown]
# App

# %%
import pandas as pd

# Loading dataset
file_path = '/content/classified_documents_with_topics.csv'
data = pd.read_csv(file_path)

# Displaying the first few rows
print(data.head())
# Check for missing values and data types
print(data.info())
print(data['topic_label'].value_counts())  # Assuming 'Label' column for category labels
# Out:
#           Date                                              Title  \
# 0  28 Sep 2024  Forvia Hella begins making RGB LED rear combin...
# 1  28 Sep 2024  Continental named among top 500 sustainable co...
# 2  28 Sep 2024  Stellantis honours 68 global and regional supp...
# 3  27 Sep 2024  Schaeffler names new CFO ahead of expected mer...
# 4  27 Sep 2024  China requests US to stop 'unreasonable suppre...
#
#                   Author                                               Tags  \
# 0  Autocar Pro News Desk  ['Lynk & Co', 'Geely Auto', 'Forvia Hella', 'R...
# 1  Autocar Pro News Desk  ['Continental', 'Continental Tires', "world's ...
# 2  Autocar Pro News Desk  ['Stellantis', 'Stellantis Supplier of the Yea...
# 3  Autocar Pro News Desk             ['Vitesco Technologies', 'Schaeffler']
# 4  Autocar Pro News Desk                                                 []
#
#    Related Organzation                                            Content  \
# 0                  NaN  The rear lamp is used in the Geely Auto Group’...
# 1                  NaN  Continental ranked 265th in Time and Statista’...
# 2                  NaN  Fourth annual Stellantis Supplier of the Year ...
# 3                  NaN  Schaeffler has also announced the appointment ...
# 4                  NaN  "The U.S. move has no factual basis, violates ...
#
#                                                 Link  \
# 0  https://www.autocarpro.in/news-international/f...
# 1  https://www.autocarpro.in/news-international/c...
# 2  https://www.autocarpro.in/news-international/s...
# 3  https://www.autocarpro.in/news-international/s...
# 4  https://www.autocarpro.in/news-international/c...
#
#                                               Tokens  topic  \
# 0  ['The', 'rear', 'lamp', 'is', 'used', 'in', 't...     35
# 1  ['Continental', 'ranked', '265th', 'in', 'Time...     27
# 2  ['Fourth', 'annual', 'Stellantis', 'Supplier',...     29
# 3  ['Schaeffler', 'has', 'also', 'announced', 'th...     28
# 4  ['``', 'The', 'U.S.', 'move', 'has', 'no', 'fa...     32
#
#                                    topic_label  probability
# 0                   Natural Disasters, Finance          1.0
# 1  Geopolitical, Regulatory, Natural Disasters          1.0
# 2                                      Finance          1.0
# 3                        Geopolitical, Finance          1.0
# 4                            Natural Disasters          1.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2008 entries, 0 to 2007
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 2008 non-null   object
#  1   Title                2008 non-null   object
#  2   Author               1008 non-null   object
#  3   Tags                 2008 non-null   object
#  4   Related Organzation  0 non-null      float64
#  5   Content              2008 non-null   object
#  6   Link                 2008 non-null   object
#  7   Tokens               2008 non-null   object
#  8   topic                2008 non-null   int64
#  9   topic_label          2008 non-null   object
#  10  probability          2008 non-null   float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 172.7+ KB
# None
# topic_label
# Finance,Geopolitical, Natural Disasters, Regulatory     760
# Geopolitical, Natural Disasters, Regulatory             132
# Regulatory, Finance, Natural Disasters                  127
# Finance, Geopolitical, Regulatory                       116
# Natural Disasters, Geopolitical, Regulatory             103
# Finance, Regulatory, Geopolitical                        92
# Natural Disasters, Finance, Regulatory                   82
# Geopolitical, Finance, Regulatory                        70
# Finance, Natural Disasters, Geopolitical                 57
# Finance                                                  52
# Geopolitical, Finance                                    50
# Natural Disasters, Finance, Geopolitical, Regulatory     48
# Natural Disasters, Geopolitical, Finance, Regulatory     43
# Regulatory, Geopolitical, Natural Disasters              41
# Geopolitical, Finance, Regulatory, Natural Disasters     38
# Regulatory, Geopolitical, Finance, Natural Disasters     31
# Natural Disasters, Regulatory                            28
# Finance, Regulatory, Natural Disasters                   25
# Natural Disasters, Finance                               24
# Natural Disasters, Regulatory, Finance                   23
# Regulatory, Geopolitical                                 22
# Geopolitical, Regulatory, Natural Disasters              20
# Natural Disasters                                        13
# Geopolitical, Regulatory                                 11
# Name: count, dtype: int64

# %%
import pandas as pd

# Load dataset
file_path = '/content/classified_documents_with_topics.csv'
data = pd.read_csv(file_path)

# Define categories and create binary columns for multi-label classification
categories = ["Finance", "Geopolitical", "Natural Disasters", "Regulatory"]

# Split labels and create binary columns
for category in categories:
    data[category] = data['topic_label'].apply(lambda x: int(category in x))

# Verify binary columns
print(data[categories].head())
# Out:
#    Finance  Geopolitical  Natural Disasters  Regulatory
# 0        1             0                  1           0
# 1        0             1                  1           1
# 2        1             0                  0           0
# 3        1             1                  0           0
# 4        0             0                  1           0

# %%
import re

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# Basic text preprocessing
data['Content'] = data['Content'].apply(lambda x: re.sub(r'\W', ' ', str(x)).lower())

# Split the data for training and validation
X_train, X_val, y_train, y_val = train_test_split(
    data['Content'], data[categories], test_size=0.2, random_state=42
)

# TF-IDF feature extraction
tfidf = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf.fit_transform(X_train)
X_val_tfidf = tfidf.transform(X_val)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Use class_weight='balanced' to adjust for imbalance
model = OneVsRestClassifier(LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42))
model.fit(X_train_tfidf, y_train)
# Make predictions
y_pred = model.predict(X_val_tfidf)

# Evaluation
print(classification_report(y_val, y_pred, target_names=categories))
# Out:
#                    precision    recall  f1-score   support
#
#           Finance       0.95      0.88      0.91       333
#      Geopolitical       0.95      0.88      0.92       330
# Natural Disasters       0.94      0.93      0.93       329
#        Regulatory       0.98      0.96      0.97       366
#
#         micro avg       0.95      0.92      0.93      1358
#         macro avg       0.95      0.91      0.93      1358
#      weighted avg       0.95      0.92      0.93      1358
#       samples avg       0.96      0.92      0.93      1358

# %%
from sklearn.metrics import hamming_loss, f1_score

# Calculate Hamming loss
print("Hamming Loss:", hamming_loss(y_val, y_pred))

# Calculate F1 score
print("F1 Score (micro):", f1_score(y_val, y_pred, average='micro'))
print("F1 Score (macro):", f1_score(y_val, y_pred, average='macro'))
# Out:
# Hamming Loss: 0.10758706467661691
# F1 Score (micro): 0.9349868470499813
# F1 Score (macro): 0.9337978092855136
